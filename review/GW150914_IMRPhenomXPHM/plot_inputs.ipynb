# %%
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")

import numpy as np 
import h5ify 
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import importlib
import json

import sys
sys.path.append('/mnt/home/smiller/src/time-domain-gw-inference/')
from time_domain_gw_inference import group_postprocess, utils, run_sampler

importlib.reload(group_postprocess)
importlib.reload(run_sampler)
# Out:
# <module 'time_domain_gw_inference.run_sampler' from '/mnt/home/smiller/src/time-domain-gw-inference/time_domain_gw_inference/run_sampler.py'>

# %% [markdown]
# ### Load likelihood manager

# %%
 # Get likelihood manager
data = group_postprocess.load_run_settings_from_directory('./output/250619_output', filename_dict={'full':'full_0.0seconds'})
lm = data['runs']['full']['likelihood_manager']
# Out:
# key: full
# line is /mnt/home/smiller/src/time-domain-gw-inference/time_domain_gw_inference/run_sampler.py --output-h5 full_0.0seconds/full_0.0seconds.h5 --mode full --Tcut-seconds 0.0 --ifos H1 L1 --total-mass-prior-bounds 50 90 --mass-ratio-prior-bounds 0.05 1 --time-prior-sigma 0.02 --luminosity-distance-prior-bounds 100 1000 --approx IMRPhenomXPHM --ncpu 128 --nsteps 50000 --Tstart 1126259461.407382 --Tend 1126259462.707382 --sampling-rate 2048 --f22-start 20 --fref 20 --flow 20 --fmax 896 --vary-skypos  --vary-time  --resume  --pe-posterior-h5-file data_directory/IGWN-GWTC2p1-v2-GW150914_095045_PEDataRelease_mixed_cosmo.h5 --data H1:data_directory/H1_strain.h5 --data L1:data_directory/L1_strain.h5 --psd H1:data_directory/H1-psd.dat --psd L1:data_directory/L1-psd.dat  &>> full_0.0seconds/full_0.0seconds.log
#
# Using H1_time posterior to calculate t0.
# warning! neither mean_anomaly nor mean_anomaly_periastron in df.columns!
# reference_parameters are {'chirp_mass': 30.888843983365483, 'mass_ratio': 0.9495467444799741, 'a_1': 0.7782178876542204, 'a_2': 0.47212926430291474, 'tilt_1': 1.3409449949453787, 'tilt_2': 2.0878340472406536, 'phi_12': 2.808130243444072, 'phi_jl': 6.122585283944053, 'theta_jn': 2.3557458973832524, 'psi': 0.7455033030298557, 'phase': 4.465002601515748, 'azimuth': 2.4901375659105804, 'zenith': 2.3520215833179945, 'recalib_H1_amplitude_0': -0.05899760274851292, 'recalib_H1_amplitude_1': 0.026914987879917918, 'recalib_H1_amplitude_2': -0.011342311624226293, 'recalib_H1_amplitude_3': -0.00013859290555724366, 'recalib_H1_amplitude_4': 0.0026478227089553846, 'recalib_H1_amplitude_5': 0.02373241624033889, 'recalib_H1_amplitude_6': -0.0045629345426358, 'recalib_H1_amplitude_7': -0.005546191355010493, 'recalib_H1_amplitude_8': -0.023617743451481717, 'recalib_H1_amplitude_9': 0.0012758138691568173, 'recalib_H1_phase_0': 0.02581737996540041, 'recalib_H1_phase_1': -0.041281476306569635, 'recalib_H1_phase_2': 0.010337206103020764, 'recalib_H1_phase_3': -0.015381764756920093, 'recalib_H1_phase_4': -0.01728274385138675, 'recalib_H1_phase_5': -0.04588812794262504, 'recalib_H1_phase_6': 0.03820477414679136, 'recalib_H1_phase_7': -0.011761853787731593, 'recalib_H1_phase_8': -0.021207625572177338, 'recalib_H1_phase_9': 0.020681081655510986, 'recalib_L1_amplitude_0': -0.07711958895769226, 'recalib_L1_amplitude_1': -0.022387380814503
# key: full
# line is /mnt/home/smiller/src/time-domain-gw-inference/time_domain_gw_inference/run_sampler.py --output-h5 full_0.0seconds/full_0.0seconds.h5 --mode full --Tcut-seconds 0.0 --ifos H1 L1 --total-mass-prior-bounds 50 90 --mass-ratio-prior-bounds 0.05 1 --time-prior-sigma 0.02 --luminosity-distance-prior-bounds 100 1000 --approx IMRPhenomXPHM --ncpu 128 --nsteps 50000 --Tstart 1126259461.407382 --Tend 1126259462.707382 --sampling-rate 2048 --f22-start 20 --fref 20 --flow 20 --fmax 896 --vary-skypos  --vary-time  --resume  --pe-posterior-h5-file data_directory/IGWN-GWTC2p1-v2-GW150914_095045_PEDataRelease_mixed_cosmo.h5 --data H1:data_directory/H1_strain.h5 --data L1:data_directory/L1_strain.h5 --psd H1:data_directory/H1-psd.dat --psd L1:data_directory/L1-psd.dat  &>> full_0.0seconds/full_0.0seconds.log
#
# Using H1_time posterior to calculate t0.
# warning! neither mean_anomaly nor mean_anomaly_periastron in df.columns!
# reference_parameters are {'chirp_mass': 30.888843983365483, 'mass_ratio': 0.9495467444799741, 'a_1': 0.7782178876542204, 'a_2': 0.47212926430291474, 'tilt_1': 1.3409449949453787, 'tilt_2': 2.0878340472406536, 'phi_12': 2.808130243444072, 'phi_jl': 6.122585283944053, 'theta_jn': 2.3557458973832524, 'psi': 0.7455033030298557, 'phase': 4.465002601515748, 'azimuth': 2.4901375659105804, 'zenith': 2.3520215833179945, 'recalib_H1_amplitude_0': -0.05899760274851292, 'recalib_H1_amplitude_1': 0.026914987879917918, 'recalib_H1_amplitude_2': -0.011342311624226293, 'recalib_H1_amplitude_3': -0.00013859290555724366, 'recalib_H1_amplitude_4': 0.0026478227089553846, 'recalib_H1_amplitude_5': 0.02373241624033889, 'recalib_H1_amplitude_6': -0.0045629345426358, 'recalib_H1_amplitude_7': -0.005546191355010493, 'recalib_H1_amplitude_8': -0.023617743451481717, 'recalib_H1_amplitude_9': 0.0012758138691568173, 'recalib_H1_phase_0': 0.02581737996540041, 'recalib_H1_phase_1': -0.041281476306569635, 'recalib_H1_phase_2': 0.010337206103020764, 'recalib_H1_phase_3': -0.015381764756920093, 'recalib_H1_phase_4': -0.01728274385138675, 'recalib_H1_phase_5': -0.04588812794262504, 'recalib_H1_phase_6': 0.03820477414679136, 'recalib_H1_phase_7': -0.011761853787731593, 'recalib_H1_phase_8': -0.021207625572177338, 'recalib_H1_phase_9': 0.020681081655510986, 'recalib_L1_amplitude_0': -0.07711958895769226, 'recalib_L1_amplitude_1': -0.022387380814503748, 'recalib_L1_amplitude_2': -0.04198550521451003, 'recalib_L1_amplitude_3': 0.06469561888408598, 'recalib_L1_amplitude_4': 0.049366351987292494, 'recalib_L1_amplitude_5': -0.04354868190411623, 'recalib_L1_amplitude_6': 0.0027195548743734876, 'recalib_L1_amplitude_7': 0.0016282931289189227, 'recalib_L1_amplitude_8': 0.03237842543344974, 'recalib_L1_amplitude_9': -0.011321061228169872, 'recalib_L1_phase_0': 0.005535127301315529, 'recalib_L1_phase_1': 0.15172364052537976, 'recalib_L1_phase_2': -0.0443067728541626, 'recalib_L1_phase_3': 0.12543137470754698, 'recalib_L1_phase_4': -0.027374883776836896, 'recalib_L1_phase_5': 0.01791075730778724, 'recalib_L1_phase_6': -0.02599832073783031, 'recalib_L1_phase_7': -0.0010118398742631639, 'recalib_L1_phase_8': 0.008966952688370403, 'recalib_L1_phase_9': 0.01862027884230231, 'time_jitter': -0.00026667646800521334, 'luminosity_distance': 475.13956966692876, 'geocent_time': 1126259462.407382, 'recalib_H1_frequency_0': 19.999999999999996, 'recalib_H1_frequency_1': 30.514434824844255, 'recalib_H1_frequency_2': 46.55653663398341, 'recalib_H1_frequency_3': 71.03232013940804, 'recalib_H1_frequency_4': 108.37555516757195, 'recalib_H1_frequency_5': 165.35094073835938, 'recalib_H1_frequency_6': 252.27952521936786, 'recalib_H1_frequency_7': 384.9083564974527, 'recalib_H1_frequency_8': 587.2630478939719, 'recalib_H1_frequency_9': 895.9999999999999, 'recalib_L1_frequency_0': 19.999999999999996, 'recalib_L1_frequency_1': 30.514434824844255, 'recalib_L1_frequency_2': 46.55653663398341, 'recalib_L1_frequency_3': 71.03232013940804, 'recalib_L1_frequency_4': 108.37555516757195, 'recalib_L1_frequency_5': 165.35094073835938, 'recalib_L1_frequency_6': 252.27952521936786, 'recalib_L1_frequency_7': 384.9083564974527, 'recalib_L1_frequency_8': 587.2630478939719, 'recalib_L1_frequency_9': 895.9999999999999, 'log_likelihood': 324.5818658257267, 'log_prior': 72.4734599118574, 'total_mass': 70.99246057807377, 'mass_1': 36.41485426245086, 'mass_2': 34.57760631562292, 'ra': 2.3740998909517543, 'dec': -1.182031580667859, 'symmetric_mass_ratio': 0.24983256313180427, 'iota': 2.3674518382619962, 'spin_1x': -0.06691784854334148, 'spin_1y': -0.75479039380051, 'spin_1z': 0.17730353532233395, 'spin_2x': 0.16805889552555467, 'spin_2y': 0.37442952126140244, 'spin_2z': -0.23337691285536177, 'phi_1': 4.623962652915748, 'phi_2': 1.1489075891802338, 'chi_eff': -0.022722590592757386, 'chi_1_in_plane': 0.7577509729635447, 'chi_2_in_plane': 0.41041595821472676, 'chi_p': 0.7577509729635447, 'cos_tilt_1': 0.22783276783418507,  ...
# making wf manager
# getting conditioned time and data
# kwargs are:
# {'mtot_lim': [50.0, 90.0], 'q_lim': [0.05, 1.0], 'chi_lim': [0, 0.99], 'dist_lim': [100.0, 1000.0], 'sigma_time': 0.02, 'approx': 'IMRPhenomXPHM', 'f_ref': 20.0, 'f_low': 20.0, 'f22_start': 20.0, 'delta_t': 0.00048828125, 'right_ascension': 2.3740998909517543, 'declination': -1.182031580667859, 'polarization': 0.7455033030298557, 'geocenter_time': 1126259462.407382, 'verbose': False}
# key: full
# line is /mnt/home/smiller/src/time-domain-gw-inference/time_domain_gw_inference/run_sampler.py --output-h5 full_0.0seconds/full_0.0seconds.h5 --mode full --Tcut-seconds 0.0 --ifos H1 L1 --total-mass-prior-bounds 50 90 --mass-ratio-prior-bounds 0.05 1 --time-prior-sigma 0.02 --luminosity-distance-prior-bounds 100 1000 --approx IMRPhenomXPHM --ncpu 128 --nsteps 50000 --Tstart 1126259461.407382 --Tend 1126259462.707382 --sampling-rate 2048 --f22-start 20 --fref 20 --flow 20 --fmax 896 --vary-skypos  --vary-time  --resume  --pe-posterior-h5-file data_directory/IGWN-GWTC2p1-v2-GW150914_095045_PEDataRelease_mixed_cosmo.h
 475.13956966692876, 'geocent_time': 1126259462.407382, 'recalib_H1_frequency_0': 19.999999999999996, 'recalib_H1_frequency_1': 30.514434824844255, 'recalib_H1_frequency_2': 46.55653663398341, 'recalib_H1_frequency_3': 71.03232013940804, 'recalib_H1_frequency_4': 108.37555516757195, 'recalib_H1_frequency_5': 165.35094073835938, 'recalib_H1_frequency_6': 252.27952521936786, 'recalib_H1_frequency_7': 384.9083564974527, 'recalib_H1_frequency_8': 587.2630478939719, 'recalib_H1_frequency_9': 895.9999999999999, 'recalib_L1_frequency_0': 19.999999999999996, 'recalib_L1_frequency_1': 30.514434824844255, 'recalib_L1_frequency_2': 46.55653663398341, 'recalib_L1_frequency_3': 71.03232013940804, 'recalib_L1_frequency_4': 108.37555516757195, 'recalib_L1_frequency_5': 165.35094073835938, 'recalib_L1_frequency_6': 252.27952521936786, 'recalib_L1_frequency_7': 384.9083564974527, 'recalib_L1_frequency_8': 587.2630478939719, 'recalib_L1_frequency_9': 895.9999999999999, 'log_likelihood': 324.5818658257267, 'log_prior': 72.4734599118574, 'total_mass': 70.99246057807377, 'mass_1': 36.41485426245086, 'mass_2': 34.57760631562292, 'ra': 2.3740998909517543, 'dec': -1.182031580667859, 'symmetric_mass_ratio': 0.24983256313180427, 'iota': 2.3674518382619962, 'spin_1x': -0.06691784854334148, 'spin_1y': -0.75479039380051, 'spin_1z': 0.17730353532233395, 'spin_2x': 0.16805889552555467, 'spin_2y': 0.37442952126140244, 'spin_2z': -0.23337691285536177, 'phi_1': 4.623962652915748, 'phi_2': 1.1489075891802338, 'chi_eff': -0.022722590592757386, 'chi_1_in_plane': 0.7577509729635447, 'chi_2_in_plane': 0.41041595821472676, 'chi_p': 0.7577509729635447, 'cos_tilt_1': 0.22783276783418507,  ...
# making wf manager
# getting conditioned time and data
# kwargs are:
# {'mtot_lim': [50.0, 90.0], 'q_lim': [0.05, 1.0], 'chi_lim': [0, 0.99], 'dist_lim': [100.0, 1000.0], 'sigma_time': 0.02, 'approx': 'IMRPhenomXPHM', 'f_ref': 20.0, 'f_low': 20.0, 'f22_start': 20.0, 'delta_t': 0.00048828125, 'right_ascension': 2.3740998909517543, 'declination': -1.182031580667859, 'polarization': 0.7455033030298557, 'geocenter_time': 1126259462.407382, 'verbose': False}

# %% [markdown]
# ### Plot PSD

# %%
# Plot conditioned PSD
plt.figure()
for i, ifo in enumerate(lm.ifos): 
    freq, psd = lm.conditioned_psd_dict[ifo].transpose()
    plt.loglog(freq, psd, color=f'C{i}', label=ifo)
plt.xlabel('frequency')
plt.ylabel('psd')
plt.legend()
plt.xlim(10,)
plt.show()

# %% [markdown]
# ### Load FD posterior and get maxL reconstruction

# %%
# get reference parameters
FD_posterior = h5ify.load('./input/IGWN-GWTC2p1-v2-GW150914_095045_PEDataRelease_mixed_cosmo.h5')['C01:IMRPhenomXPHM']['posterior_samples']

# get maxL
imax = np.argmax(FD_posterior['log_likelihood'])
reference_parameters_ = FD_posterior[imax]
reference_parameters = {k: reference_parameters_[k] for k in reference_parameters_.dtype.names}

# %%
# Get injection
reference_parameters_transformed = run_sampler.modify_parameters(reference_parameters, data['runs']['full']['args'])
injection_dict = lm.waveform_manager.get_projected_waveform(
    reference_parameters_transformed,
    lm.ifos,
    lm.time_dict,
    lm.f22_start, 
    lm.f_ref
)
# Whiten injection
injection_dict_whitened = {ifo : utils.whitenData(
    injection_dict[ifo], 
    lm.time_dict[ifo],
    lm.conditioned_psd_dict[ifo][:, 1], 
    lm.conditioned_psd_dict[ifo][:, 0]
) for ifo in lm.ifos}
# Out:
# warning! neither mean_anomaly nor mean_anomaly_periastron in df.columns!

# %% [markdown]
# ### Plot strain

# %%
# Get detector delay times 
dt_dict = lm.waveform_manager.antenna_and_time_manager.compute_time_delay_dict(
    data['runs']['full']['kwargs']['right_ascension'], 
    data['runs']['full']['kwargs']['declination'], 
    lm.reference_time, 
    lm.ifos
)

# %%
# Colored strain 
for i, ifo in enumerate(lm.ifos): 

    times = lm.time_dict[ifo] - lm.reference_time - dt_dict[ifo]

    plt.figure(figsize=(10, 3))
    plt.plot(times, lm.data_dict[ifo], color=f'C{i}')
    plt.plot(times, injection_dict[ifo], color='k')
    plt.title(ifo)
    plt.xlabel('$t - t_0$')
    plt.ylabel('strain')
    plt.show()

# %%
# Whitened strain cropped
for i, ifo in enumerate(lm.ifos): 

    times = lm.time_dict[ifo] - lm.reference_time - dt_dict[ifo]

    plt.figure(figsize=(10, 3))
    plt.plot(times, lm.whitened_data_dict[ifo], color=f'C{i}')
    plt.plot(times, injection_dict_whitened[ifo], color='k')
    plt.title(ifo)
    plt.xlabel('$t - t_0$')
    plt.ylabel('whitened strain')
    #plt.xlim(-0.1, 0.02)
    plt.ylim(-5,5)
    plt.show()

# %%
# Whitened strain cropped
for i, ifo in enumerate(lm.ifos): 

    times = lm.time_dict[ifo] - lm.reference_time - dt_dict[ifo]

    plt.figure(figsize=(10, 3))
    plt.plot(times, lm.whitened_data_dict[ifo], color=f'C{i}')
    plt.plot(times, injection_dict_whitened[ifo], color='k')
    plt.title(ifo)
    plt.xlabel('$t - t_0$')
    plt.ylabel('whitened strain')
    plt.xlim(-0.1, 0.04)
    plt.ylim(-8,8)
    plt.show()

# %% [markdown]
# ### Cumulative SNR check

# %%
plt.plot()
for ifo in lm.ifos:
    
    times_det = lm.time_dict[ifo] - lm.reference_time - dt_dict[ifo]
    cum_snr = np.sqrt(np.cumsum(injection_dict_whitened[ifo][::-1]**2))
    
    plt.plot(times_det[::-1], cum_snr, label=ifo)
    
plt.legend()
plt.ylabel('$\propto$ cumulative SNR from end')
plt.xlabel('time from merger [s]')
plt.show()

# %%
plt.plot()
for ifo in lm.ifos:
    
    times_det = lm.time_dict[ifo] - lm.reference_time - dt_dict[ifo]
    cum_snr = np.sqrt(np.cumsum(injection_dict_whitened[ifo]**2))
    
    plt.plot(times_det, cum_snr, label=ifo)
    
plt.legend()
plt.ylabel('$\propto$ cumulative SNR from start')
plt.xlabel('time from merger [s]')
plt.show()

# %%
print('Tstart =', lm.reference_time - 1)
print('Tend =', lm.reference_time + 0.3)
# Out:
# Tstart = 1126259461.407382
# Tend = 1126259462.707382
